# %% [markdown]
# ## Load data

# %%
import numpy as np
import pandas as pd 

import os
import glob

dspaths = glob.glob('../data/csv/**/*.csv', recursive=True)

for path in dspaths:
    print(path)
# Out:
# ../data/csv\Benign-Monday-WorkingHours.pcap_ISCX.csv
# ../data/csv\Botnet-Friday-WorkingHours-Morning.pcap_ISCX.csv
# ../data/csv\Bruteforce-Tuesday-WorkingHours.pcap_ISCX.csv
# ../data/csv\DDoS-Friday-WorkingHours-Afternoon.pcap_ISCX.csv
# ../data/csv\DoS-Wednesday-WorkingHours.pcap_ISCX.csv
# ../data/csv\Infiltration-Thursday-WorkingHours-Afternoon.pcap_ISCX.csv
# ../data/csv\Portscan-Friday-WorkingHours-Afternoon.pcap_ISCX.csv
# ../data/csv\WebAttacks-Thursday-WorkingHours-Morning.pcap_ISCX.csv

# %%
# !pip install fastai fastcore
# Out:
# Requirement already satisfied: fastai in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (2.8.7)
# Requirement already satisfied: fastcore in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (1.13.6)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fasttransform>=0.0.2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (0.26.0)
# Requirement already satisfied: matplotlib in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (3.10.9)
# Requirement already satisfied: pandas in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (3.0.1)
# Requirement already satisfied: requests in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (2.32.5)
# Requirement already satisfied: pyyaml in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (6.0.3)
# Requirement already satisfied: fastprogress>=0.2.4 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (1.1.6)
# Requirement already satisfied: pillow>=9.0.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (12.1.1)
# Requirement already satisfied: scikit-learn in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (1.8.0)
# Requirement already satisfied: scipy in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (1.17.1)
# Requirement already satisfied: spacy<4 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (3.8.14)
# Requirement already satisfied: packaging in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (25.0)
# Requirement already satisfied: plum-dispatch in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (2.9.0)
# Requirement already satisfied: cloudpickle in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (3.1.2)
# Requirement already satisfied: torch<3,>=1.10 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastai) (2.11.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (0.21.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (2.12.5)
# Requirement already satisfied: jinja2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from spacy<4->fastai) (80.10.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from requests->fastai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from requests->fastai) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from requests->fastai) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from requests->fastai) (2026.4.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy<4->fastai) (1.3.3)
# Requirement already satisfied: filelock in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from torch<3,>=1.10->fastai) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from torch<3,>=1.10->fastai) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from torch<3,>=1.10->fastai) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from torch<3,>=1.10->fastai) (2026.2.0)
# Requirement already satisfied: colorama in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (14.3.3)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4->fastai) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4->fastai) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4->fastai) (0.28.1)
# Requirement already satisfied: python-fasthtml>=0.12.34 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastprogress>=0.2.4->fastai) (0.14.3)
# Requirement already satisfied: anyio in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (4.12.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (0.16.0)
# Requirement already satisfied: python-dateutil in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.9.0.post0)
# Requirement already satisfied: starlette>=1.0.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.3.1)
# Requirement already satisfied: oauthlib in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (3.3.1)
# Requirement already satisfied: itsdangerous in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.2.0)
# Requirement already satisfied: uvicorn>=0.30 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.42.0)
# Requirement already satisfied: httpx2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.4.0)
# Requirement already satisfied: fastlite>=0.1.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.2.4)
# Requirement already satisfied: python-multipart in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.0.22)
# Requirement already satisfied: beautifulsoup4 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (4.14.3)
# Requirement already satisfied: apswutils>=0.1.2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.1.2)
# Requirement already satisfied: apsw in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (3.53.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (2.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from sympy>=1.13.3->torch<3,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.2.2)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from beautifulsoup4->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.8.3)
# Requirement already satisfied: httpcore2==2.4.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from httpx2->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.4.0)
# Requirement already satisfied: truststore>=0.10 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from httpx2->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.10.4)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from jinja2->spacy<4->fastai) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from matplotlib->fastai) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from matplotlib->fastai) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from matplotlib->fastai) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from matplotlib->fastai) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from python-dateutil->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.17.0)
# Requirement already satisfied: tzdata in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from pandas->fastai) (2025.3)
# Requirement already satisfied: beartype>=0.16.2 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from plum-dispatch->fastai) (0.22.9)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from scikit-learn->fastai) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\User\anaconda3\envs\machine_learning\Lib\site-packages (from scikit-learn->fastai) (3.6.0)

# %%
from fastai.tabular.all import df_shrink
from fastcore.parallel import *

# %%
col_name_consistency = {
'Destination Port': 'Destination Port',
'Dst Port': 'Destination Port',
'Flow Duration': 'Flow Duration',
'Total Fwd Packets': 'Total Fwd Packets',
'Tot Fwd Pkts': 'Total Fwd Packets',
'Total Backward Packets': 'Total Backward Packets',
'Tot Bwd Pkts': 'Total Backward Packets',
'Total Length of Fwd Packets': 'Fwd Packets Length Total',
'TotLen Fwd Pkts': 'Fwd Packets Length Total',
'Total Length of Bwd Packets': 'Bwd Packets Length Total',
'TotLen Bwd Pkts': 'Bwd Packets Length Total',
'Fwd Packet Length Max': 'Fwd Packet Length Max',
'Fwd Pkt Len Max': 'Fwd Packet Length Max',
'Fwd Packet Length Min': 'Fwd Packet Length Min',
'Fwd Pkt Len Min': 'Fwd Packet Length Min',
'Fwd Packet Length Mean': 'Fwd Packet Length Mean',
'Fwd Pkt Len Mean': 'Fwd Packet Length Mean',
'Fwd Packet Length Std': 'Fwd Packet Length Std',
'Fwd Pkt Len Std': 'Fwd Packet Length Std',
'Bwd Packet Length Max': 'Bwd Packet Length Max',
'Bwd Pkt Len Max': 'Bwd Packet Length Max',
'Bwd Packet Length Min': 'Bwd Packet Length Min',
'Bwd Pkt Len Min': 'Bwd Packet Length Min',
'Bwd Packet Length Mean': 'Bwd Packet Length Mean',
'Bwd Pkt Len Mean': 'Bwd Packet Length Mean',
'Bwd Packet Length Std': 'Bwd Packet Length Std',
'Bwd Pkt Len Std': 'Bwd Packet Length Std',
'Flow Bytes/s': 'Flow Bytes/s',
'Flow Byts/s': 'Flow Bytes/s',
'Flow Packets/s': 'Flow Packets/s',
'Flow Pkts/s': 'Flow Packets/s',
'Flow IAT Mean': 'Flow IAT Mean',
'Flow IAT Std': 'Flow IAT Std',
'Flow IAT Max': 'Flow IAT Max',
'Flow IAT Min': 'Flow IAT Min',
'Fwd IAT Total': 'Fwd IAT Total',
'Fwd IAT Tot': 'Fwd IAT Total',
'Fwd IAT Mean': 'Fwd IAT Mean',
'Fwd IAT Std': 'Fwd IAT Std',
'Fwd IAT Max': 'Fwd IAT Max',
'Fwd IAT Min': 'Fwd IAT Min',
'Bwd IAT Total': 'Bwd IAT Total',
'Bwd IAT Tot': 'Bwd IAT Total',
'Bwd IAT Mean': 'Bwd IAT Mean',
'Bwd IAT Std': 'Bwd IAT Std',
'Bwd IAT Max': 'Bwd IAT Max',
'Bwd IAT Min': 'Bwd IAT Min',
'Fwd PSH Flags': 'Fwd PSH Flags',
'Bwd PSH Flags': 'Bwd PSH Flags',
'Fwd URG Flags': 'Fwd URG Flags',
'Bwd URG Flags': 'Bwd URG Flags',
'Fwd Header Length': 'Fwd Header Length',
'Fwd Header Len': 'Fwd Header Length',
'Bwd Header Length': 'Bwd Header Length',
'Bwd Header Len': 'Bwd Header Length',
'Fwd Packets/s': 'Fwd Packets/s',
'Fwd Pkts/s': 'Fwd Packets/s',
'Bwd Packets/s': 'Bwd Packets/s',
'Bwd Pkts/s': 'Bwd Packets/s',
'Min Packet Length': 'Packet Length Min',
'Pkt Len Min': 'Packet Length Min',
'Max Packet Length': 'Packet Length Max',
'Pkt Len Max': 'Packet Length Max',
'Packet Length Mean': 'Packet Length Mean',
'Pkt Len Mean': 'Packet Length Mean',
'Packet Length Std': 'Packet Length Std',
'Pkt Len Std': 'Packet Length Std',
'Packet Length Variance': 'Packet Length Variance',
'Pkt Len Var': 'Packet Length Variance',
'FIN Flag Count': 'FIN Flag Count',
'FIN Flag Cnt': 'FIN Flag Count',
'SYN Flag Count': 'SYN Flag Count',
'SYN Flag Cnt': 'SYN Flag Count',
'RST Flag Count': 'RST Flag Count',
'RST Flag Cnt': 'RST Flag Count',
'PSH Flag Count': 'PSH Flag Count',
'PSH Flag Cnt': 'PSH Flag Count',
'ACK Flag Count': 'ACK Flag Count',
'ACK Flag Cnt': 'ACK Flag Count',
'URG Flag Count': 'URG Flag Count',
'URG Flag Cnt': 'URG Flag Count',
'CWE Flag Count': 'CWE Flag Count',
'CWE Flag Cnt': 'CWE Flag Count',
'ECE Flag Count': 'ECE Flag Count',
'ECE Flag Cnt': 'ECE Flag Count',
'Down/Up Ratio': 'Down/Up Ratio',
'Average Packet Size': 'Avg Packet Size',
'Pkt Size Avg': 'Avg Packet Size',
'Avg Fwd Segment Size': 'Avg Fwd Segment Size',
'Fwd Seg Size Avg': 'Avg Fwd Segment Size',
'Avg Bwd Segment Size': 'Avg Bwd Segment Size',
'Bwd Seg Size Avg': 'Avg Bwd Segment Size',
'Fwd Avg Bytes/Bulk': 'Fwd Avg Bytes/Bulk',
'Fwd Byts/b Avg': 'Fwd Avg Bytes/Bulk',
'Fwd Avg Packets/Bulk': 'Fwd Avg Packets/Bulk',
'Fwd Pkts/b Avg': 'Fwd Avg Packets/Bulk',
'Fwd Avg Bulk Rate': 'Fwd Avg Bulk Rate',
'Fwd Blk Rate Avg': 'Fwd Avg Bulk Rate',
'Bwd Avg Bytes/Bulk': 'Bwd Avg Bytes/Bulk',
'Bwd Byts/b Avg': 'Bwd Avg Bytes/Bulk',
'Bwd Avg Packets/Bulk': 'Bwd Avg Packets/Bulk',
'Bwd Pkts/b Avg': 'Bwd Avg Packets/Bulk',
'Bwd Avg Bulk Rate': 'Bwd Avg Bulk Rate',
'Bwd Blk Rate Avg': 'Bwd Avg Bulk Rate',
'Subflow Fwd Packets': 'Subflow Fwd Packets',
'Subflow Fwd Pkts': 'Subflow Fwd Packets',
'Subflow Fwd Bytes': 'Subflow Fwd Bytes',
'Subflow Fwd Byts': 'Subflow Fwd Bytes',
'Subflow Bwd Packets': 'Subflow Bwd Packets',
'Subflow Bwd Pkts': 'Subflow Bwd Packets',
'Subflow Bwd Bytes': 'Subflow Bwd Bytes',
'Subflow Bwd Byts': 'Subflow Bwd Bytes',
'Init_Win_bytes_forward': 'Init Fwd Win Bytes',
'Init Fwd Win Byts': 'Init Fwd Win Bytes',
'Init_Win_bytes_backward': 'Init Bwd Win Bytes',
'Init Bwd Win Byts': 'Init Bwd Win Bytes',
'act_data_pkt_fwd': 'Fwd Act Data Packets',
'Fwd Act Data Pkts': 'Fwd Act Data Packets',
'min_seg_size_forward': 'Fwd Seg Size Min',
'Fwd Seg Size Min': 'Fwd Seg Size Min',
'Active Mean': 'Active Mean',
'Active Std': 'Active Std',
'Active Max': 'Active Max',
'Active Min': 'Active Min',
'Idle Mean': 'Idle Mean',
'Idle Std': 'Idle Std',
'Idle Max': 'Idle Max',
'Idle Min': 'Idle Min',
'Label': 'Label'
}

# %%
drop_columns = [
    'Fwd Header Length.1',
    "Destination Port", "Dst Port"
]

# %%
individual_dfs = [pd.read_csv(dsp, sep=',', encoding='utf-8') for dsp in dspaths]
[i.shape for i in individual_dfs]
# Out:
# [(529918, 79),
#  (191033, 79),
#  (445909, 79),
#  (225745, 79),
#  (692703, 79),
#  (288602, 79),
#  (286467, 79),
#  (170366, 79)]

# %% [markdown]
# ## Drop and rename columns

# %%
for df in individual_dfs:
    df.columns = df.columns.str.strip()
    df.drop(columns=drop_columns, inplace=True, errors='ignore')    
    df.rename(columns=col_name_consistency, inplace=True)
    df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
[i.shape for i in individual_dfs]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12396\873203894.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12396\873203894.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12396\873203894.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12396\873203894.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12396\873203894.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12396\873203894.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12396\873203894.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12396\873203894.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Label'].replace({'BENIGN': 'Benign'}, inplace=True)
# [(529918, 77),
#  (191033, 77),
#  (445909, 77),
#  (225745, 77),
#  (692703, 77),
#  (288602, 77),
#  (286467, 77),
#  (170366, 77)]

# %%
individual_dfs[0].dtypes
# Out:
# Flow Duration                 int64
# Total Fwd Packets             int64
# Total Backward Packets        int64
# Fwd Packets Length Total      int64
# Bwd Packets Length Total      int64
#                              ...
# Idle Mean                   float64
# Idle Std                    float64
# Idle Max                      int64
# Idle Min                      int64
# Label                           str
# Length: 77, dtype: object

# %% [markdown]
# ## Downsizing

# %%
individual_dfs = parallel(f=df_shrink, items=individual_dfs, progress=True)

# %%
individual_dfs[0].dtypes
# Out:
# Flow Duration                 int32
# Total Fwd Packets             int32
# Total Backward Packets        int32
# Fwd Packets Length Total      int32
# Bwd Packets Length Total      int32
#                              ...
# Idle Mean                   float32
# Idle Std                    float32
# Idle Max                      int32
# Idle Min                      int32
# Label                           str
# Length: 77, dtype: object

# %% [markdown]
# ## Removing NaN

# %%
for df in individual_dfs:
    df.replace([np.inf, -np.inf], np.nan, inplace=True)    
    # print(df.isna().any(axis=1).sum(), "rows with at least one NaN to remove")
    df.dropna(inplace=True)    
[i.shape for i in individual_dfs]
# Out:
# [(529481, 77),
#  (190911, 77),
#  (445645, 77),
#  (225711, 77),
#  (691406, 77),
#  (288395, 77),
#  (286096, 77),
#  (170231, 77)]

# %% [markdown]
# ## Dropping duplicates

# %%
for df in individual_dfs:
    print(df.duplicated().sum(), "fully duplicate rows to remove")
    df.drop_duplicates(inplace=True)
    df.reset_index(inplace=True, drop=True)
[i.shape for i in individual_dfs]
# Out:
# 70650 fully duplicate rows to remove
# 14873 fully duplicate rows to remove
# 55931 fully duplicate rows to remove
# 4447 fully duplicate rows to remove
# 106415 fully duplicate rows to remove
# 80765 fully duplicate rows to remove
# 166574 fully duplicate rows to remove
# 14411 fully duplicate rows to remove
# [(458831, 77),
#  (176038, 77),
#  (389714, 77),
#  (221264, 77),
#  (584991, 77),
#  (207630, 77),
#  (119522, 77),
#  (155820, 77)]

# %%
for i, df in enumerate(individual_dfs):                                                                                                                                                            
    filename = os.path.basename(dspaths[i]).replace('.csv', '.parquet')                                                                                                                            
    df.to_parquet(f"../data/parquet/{filename}")
